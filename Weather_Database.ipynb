# %%
# Import the dependencies

import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | vestmannaeyjar
# Processing Record 4 of Set 1 | tacuarembo
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | wajima
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | bogorodskoye
# Processing Record 11 of Set 1 | caravelas
# Processing Record 12 of Set 1 | bloomingdale
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | gorin
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | axim
# Processing Record 18 of Set 1 | cruzeiro do sul
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | fort nelson
# Processing Record 21 of Set 1 | el balyana
# City not found. Skipping...
# Processing Record 22 of Set 1 | severo-kurilsk
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | santa rosa
# Processing Record 25 of Set 1 | camacha
# Processing Record 26 of Set 1 | teahupoo
# Processing Record 27 of Set 1 | abu dhabi
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | arona
# Processing Record 31 of Set 1 | marsaxlokk
# Processing Record 32 of Set 1 | nuuk
# Processing Record 33 of Set 1 | bambous virieux
# Processing Record 34 of Set 1 | prince rupert
# Processing Record 35 of Set 1 | chilliwack
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | timra
# Processing Record 39 of Set 1 | avera
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | banjar
# Processing Record 42 of Set 1 | dingle
# Processing Record 43 of Set 1 | touros
# Processing Record 44 of Set 1 | bantry
# Processing Record 45 of Set 1 | kaitangata
# Processing Record 46 of Set 1 | vila
# Processing Record 47 of Set 1 | yar-sale
# Processing Record 48 of Set 1 | makakilo city
# Processing Record 49 of Set 1 | beruwala
# Processing Record 50 of Set 1 | cherskiy
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | salta
# Processing Record 3 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | svencioneliai
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | lumphat
# Processing Record 8 of Set 2 | luderitz
# Processing Record 9 of Set 2 | laguna
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | juneau
# Processing Record 12 of Set 2 | tashtyp
# Processing Record 13 of Set 2 | guerrero negro
# Processing Record 14 of Set 2 | pisco
# Processing Record 15 of Set 2 | sao lourenco do oeste
# Processing Record 16 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | mount gambier
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | kalevala
# Processing Record 22 of Set 2 | jinotepe
# Processing Record 23 of Set 2 | sudak
# Processing Record 24 of Set 2 | oksbol
# Processing Record 25 of Set 2 | tambura
# Processing Record 26 of Set 2 | naze
# Processing Record 27 of Set 2 | lodja
# Processing Record 28 of Set 2 | bandar-e lengeh
# Processing Record 29 of Set 2 | yulara
# Processing Record 30 of Set 2 | tacuati
# Processing Record 31 of Set 2 | henderson
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | portland
# Processing Record 34 of Set 2 | san patricio
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | mateszalka
# Processing Record 37 of Set 2 | kapaa
# Processing Record 38 of Set 2 | pevek
# Processing Record 39 of Set 2 | suntar
# Processing Record 40 of Set 2 | albany
# Processing Record 41 of Set 2 | tomatlan
# Processing Record 42 of Set 2 | salalah
# Processing Record 43 of Set 2 | san cristobal
# Processing Record 44 of Set 2 | carnarvon
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | ixtapa
# Processing Record 49 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | saldanha
# Processing Record 2 of Set 3 | saint anthony
# Processing Record 3 of Set 3 | nautla
# Processing Record 4 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 6 of Set 3 | flin flon
# Processing Record 7 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 3 | koslan
# Processing Record 9 of Set 3 | igboho
# Processing Record 10 of Set 3 | cayenne
# Processing Record 11 of Set 3 | naliya
# Processing Record 12 of Set 3 | mar del plata
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 3 | trelew
# Processing Record 16 of Set 3 | husavik
# Processing Record 17 of Set 3 | sakakah
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | sibu
# Processing Record 20 of Set 3 | kahului
# Processing Record 21 of Set 3 | comodoro rivadavia
# Processing Record 22 of Set 3 | vondrozo
# Processing Record 23 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 3 | tual
# Processing Record 25 of Set 3 | danielskuil
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | mpika
# Processing Record 28 of Set 3 | talnakh
# Processing Record 29 of Set 3 | yuzhno-kurilsk
# Processing Record 30 of Set 3 | sabha
# Processing Record 31 of Set 3 | quelimane
# Processing Record 32 of Set 3 | sorsk
# Processing Record 33 of Set 3 | gorele
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | isla mujeres
# Processing Record 37 of Set 3 | te anau
# Processing Record 38 of Set 3 | linxia
# Processing Record 39 of Set 3 | lata
# Processing Record 40 of Set 3 | sobolevo
# Processing Record 41 of Set 3 | lamar
# Processing Record 42 of Set 3 | mahebourg
# Processing Record 43 of Set 3 | isangel
# Processing Record 44 of Set 3 | nurota
# Processing Record 45 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 3 | akdepe
# Processing Record 47 of Set 3 | flinders
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | ilulissat
# Processing Record 50 of Set 3 | sterling
# Processing Record 1 of Set 4 | lorengau
# Processing Record 2 of Set 4 | buchanan
# Processing Record 3 of Set 4 | omis
# Processing Record 4 of Set 4 | mozarlandia
# Processing Record 5 of Set 4 | fortuna
# Processing Record 6 of Set 4 | oyama
# Processing Record 7 of Set 4 | plymouth
# Processing Record 8 of Set 4 | sarangani
# Processing Record 9 of Set 4 | gornyy
# Processing Record 10 of Set 4 | wennigsen
# Processing Record 11 of Set 4 | alyangula
# Processing Record 12 of Set 4 | goderich
# Processing Record 13 of Set 4 | brisbane
# Processing Record 14 of Set 4 | hithadhoo
# Processing Record 15 of Set 4 | airai
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | southbridge
# Processing Record 18 of Set 4 | hermanus
# Processing Record 19 of Set 4 | conde
# Processing Record 20 of Set 4 | kavieng
# Processing Record 21 of Set 4 | richards bay
# Processing Record 22 of Set 4 | bubaque
# Processing Record 23 of Set 4 | cidreira
# Processing Record 24 of Set 4 | hasaki
# Processing Record 25 of Set 4 | hay river
# Processing Record 26 of Set 4 | katsuura
# Processing Record 27 of Set 4 | zapolyarnyy
# Processing Record 28 of Set 4 | port alfred
# Processing Record 29 of Set 4 | tokur
# Processing Record 30 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 4 | tevaitoa
# Processing Record 32 of Set 4 | nelson bay
# Processing Record 33 of Set 4 | bonavista
# Processing Record 34 of Set 4 | lompoc
# Processing Record 35 of Set 4 | acarau
# Processing Record 36 of Set 4 | vincennes
# Processing Record 37 of Set 4 | bethel
# Processing Record 38 of Set 4 | victoria
# Processing Record 39 of Set 4 | del rio
# Processing Record 40 of Set 4 | sagua la grande
# Processing Record 41 of Set 4 | tuatapere
# Processing Record 42 of Set 4 | kavaratti
# Processing Record 43 of Set 4 | nampula
# Processing Record 44 of Set 4 | argentan
# Processing Record 45 of Set 4 | marienburg
# Processing Record 46 of Set 4 | inta
# Processing Record 47 of Set 4 | takoradi
# Processing Record 48 of Set 4 | marysville
# Processing Record 49 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 4 | codrington
# Processing Record 1 of Set 5 | lagoa
# Processing Record 2 of Set 5 | vaini
# Processing Record 3 of Set 5 | kuminskiy
# Processing Record 4 of Set 5 | elban
# Processing Record 5 of Set 5 | palembang
# Processing Record 6 of Set 5 | sola
# Processing Record 7 of Set 5 | ponta delgada
# Processing Record 8 of Set 5 | kodiak
# Processing Record 9 of Set 5 | lavrentiya
# Processing Record 10 of Set 5 | sulangan
# Processing Record 11 of Set 5 | tambovka
# Processing Record 12 of Set 5 | komsomolskiy
# Processing Record 13 of Set 5 | jalu
# Processing Record 14 of Set 5 | bloemfontein
# Processing Record 15 of Set 5 | beeville
# Processing Record 16 of Set 5 | norman wells
# Processing Record 17 of Set 5 | torbay
# Processing Record 18 of Set 5 | clyde river
# Processing Record 19 of Set 5 | kutum
# Processing Record 20 of Set 5 | nantong
# Processing Record 21 of Set 5 | constitucion
# Processing Record 22 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 5 | pemangkat
# Processing Record 24 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 5 | betong
# Processing Record 26 of Set 5 | maraba
# Processing Record 27 of Set 5 | csomor
# Processing Record 28 of Set 5 | srednekolymsk
# Processing Record 29 of Set 5 | manakara
# Processing Record 30 of Set 5 | thompson
# Processing Record 31 of Set 5 | lufkin
# Processing Record 32 of Set 5 | florida
# Processing Record 33 of Set 5 | tyrma
# Processing Record 34 of Set 5 | quatre cocos
# Processing Record 35 of Set 5 | teguldet
# Processing Record 36 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 37 of Set 5 | nome
# Processing Record 38 of Set 5 | sinnamary
# Processing Record 39 of Set 5 | kaeo
# Processing Record 40 of Set 5 | kokstad
# Processing Record 41 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 5 | northam
# Processing Record 43 of Set 5 | port macquarie
# Processing Record 44 of Set 5 | saint george
# Processing Record 45 of Set 5 | bykovo
# Processing Record 46 of Set 5 | ozark
# Processing Record 47 of Set 5 | yeletskiy
# City not found. Skipping...
# Processing Record 48 of Set 5 | smithers
# Processing Record 49 of Set 5 | nouakchott
# Processing Record 50 of Set 5 | stromness
# Processing Record 1 of Set 6 | sao filipe
# Processing Record 2 of Set 6 | parras
# City not found. Skipping...
# Processing Record 3 of Set 6 | salinas
# Processing Record 4 of Set 6 | naantali
# Processing Record 5 of Set 6 | broome
# Processing Record 6 of Set 6 | jurm
# Processing Record 7 of Set 6 | najran
# Processing Record 8 of Set 6 | souillac
# Processing Record 9 of Set 6 | lumeje
# Processing Record 10 of Set 6 | lyubeshiv
# City not found. Skipping...
# Processing Record 11 of Set 6 | gashua
# Processing Record 12 of Set 6 | skelleftea
# Processing Record 13 of Set 6 | karratha
# Processing Record 14 of Set 6 | tiksi
# Processing Record 15 of Set 6 | pangai
# Processing Record 16 of Set 6 | koumac
# Processing Record 17 of Set 6 | san carlos de bariloche
# Processing Record 18 of Set 6 | bilma
# Processing Record 19 of Set 6 | kawalu
# Processing Record 20 of Set 6 | berlevag
# Processing Record 21 of Set 6 | road town
# Processing Record 22 of Set 6 | birjand
# Processing Record 23 of Set 6 | walvis bay
# Processing Record 24 of Set 6 | kyshtovka
# Processing Record 25 of Set 6 | ahipara
# Processing Record 26 of Set 6 | suamico
# Processing Record 27 of Set 6 | chuy
# Processing Record 28 of Set 6 | la macarena
# Processing Record 29 of Set 6 | cam ranh
# Processing Record 30 of Set 6 | benguela
# Processing Record 31 of Set 6 | qaqortoq
# Processing Record 32 of Set 6 | fare
# Processing Record 33 of Set 6 | college
# Processing Record 34 of Set 6 | porto-vecchio
# Processing Record 35 of Set 6 | saskylakh
# Processing Record 36 of Set 6 | mayo
# Processing Record 37 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 38 of Set 6 | manacapuru
# Processing Record 39 of Set 6 | geraldton
# Processing Record 40 of Set 6 | korla
# Processing Record 41 of Set 6 | coahuayana
# Processing Record 42 of Set 6 | nizhnyaya omka
# Processing Record 43 of Set 6 | dickinson
# Processing Record 44 of Set 6 | bajil
# Processing Record 45 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 6 | umm lajj
# Processing Record 47 of Set 6 | itatuba
# Processing Record 48 of Set 6 | matara
# Processing Record 49 of Set 6 | ribeira grande
# Processing Record 50 of Set 6 | bombay
# Processing Record 1 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 7 | dutlwe
# Processing Record 3 of Set 7 | waslala
# Processing Record 4 of Set 7 | san quintin
# Processing Record 5 of Set 7 | port ellen
# City not found. Skipping...
# Processing Record 6 of Set 7 | ancud
# Processing Record 7 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 7 | port-gentil
# Processing Record 9 of Set 7 | shingu
# Processing Record 10 of Set 7 | henties bay
# Processing Record 11 of Set 7 | zyryanka
# Processing Record 12 of Set 7 | cao bang
# Processing Record 13 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 7 | maralal
# Processing Record 15 of Set 7 | piacabucu
# Processing Record 16 of Set 7 | trinidad
# Processing Record 17 of Set 7 | hilo
# Processing Record 18 of Set 7 | dhenkanal
# Processing Record 19 of Set 7 | srandakan
# Processing Record 20 of Set 7 | koungou
# Processing Record 21 of Set 7 | mashhad
# Processing Record 22 of Set 7 | ljubimec
# City not found. Skipping...
# Processing Record 23 of Set 7 | udachnyy
# Processing Record 24 of Set 7 | san juan
# Processing Record 25 of Set 7 | cabo san lucas
# Processing Record 26 of Set 7 | palmerston
# Processing Record 27 of Set 7 | tiznit
# Processing Record 28 of Set 7 | san jeronimo
# Processing Record 29 of Set 7 | kieta
# Processing Record 30 of Set 7 | north bend
# Processing Record 31 of Set 7 | ambilobe
# Processing Record 32 of Set 7 | semnan
# Processing Record 33 of Set 7 | danilov
# Processing Record 34 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 7 | westport
# Processing Record 36 of Set 7 | riyadh
# Processing Record 37 of Set 7 | sitka
# Processing Record 38 of Set 7 | ponnani
# Processing Record 39 of Set 7 | asau
# Processing Record 40 of Set 7 | kohat
# Processing Record 41 of Set 7 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 42 of Set 7 | ziro
# Processing Record 43 of Set 7 | tautira
# Processing Record 44 of Set 7 | mersing
# Processing Record 45 of Set 7 | hoquiam
# Processing Record 46 of Set 7 | porto novo
# Processing Record 47 of Set 7 | hirara
# Processing Record 48 of Set 7 | kungurtug
# Processing Record 49 of Set 7 | rawson
# Processing Record 50 of Set 7 | wanxian
# Processing Record 1 of Set 8 | aklavik
# Processing Record 2 of Set 8 | nerchinskiy zavod
# Processing Record 3 of Set 8 | shelburne
# Processing Record 4 of Set 8 | lejanias
# Processing Record 5 of Set 8 | tuktoyaktuk
# Processing Record 6 of Set 8 | bengkulu
# Processing Record 7 of Set 8 | dorado
# Processing Record 8 of Set 8 | kismayo
# Processing Record 9 of Set 8 | sassandra
# Processing Record 10 of Set 8 | muros
# Processing Record 11 of Set 8 | provideniya
# Processing Record 12 of Set 8 | beaverlodge
# Processing Record 13 of Set 8 | ostrovnoy
# Processing Record 14 of Set 8 | byron bay
# Processing Record 15 of Set 8 | bowen
# Processing Record 16 of Set 8 | cluses
# Processing Record 17 of Set 8 | maxixe
# Processing Record 18 of Set 8 | luba
# Processing Record 19 of Set 8 | longyearbyen
# Processing Record 20 of Set 8 | coaldale
# Processing Record 21 of Set 8 | maneadero
# Processing Record 22 of Set 8 | havre-saint-pierre
# Processing Record 23 of Set 8 | aracaju
# Processing Record 24 of Set 8 | tateyama
# Processing Record 25 of Set 8 | hualmay
# Processing Record 26 of Set 8 | santa maria
# Processing Record 27 of Set 8 | talcahuano
# Processing Record 28 of Set 8 | dunedin
# Processing Record 29 of Set 8 | piuma
# Processing Record 30 of Set 8 | simpang
# Processing Record 31 of Set 8 | tabulbah
# City not found. Skipping...
# Processing Record 32 of Set 8 | jumla
# Processing Record 33 of Set 8 | catuday
# Processing Record 34 of Set 8 | port shepstone
# Processing Record 35 of Set 8 | chum phae
# Processing Record 36 of Set 8 | poum
# Processing Record 37 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 38 of Set 8 | vao
# Processing Record 39 of Set 8 | margate
# Processing Record 40 of Set 8 | port blair
# Processing Record 41 of Set 8 | salamina
# Processing Record 42 of Set 8 | svetlyy
# Processing Record 43 of Set 8 | biltine
# Processing Record 44 of Set 8 | general roca
# Processing Record 45 of Set 8 | kelso
# Processing Record 46 of Set 8 | faanui
# Processing Record 47 of Set 8 | denpasar
# Processing Record 48 of Set 8 | rocha
# Processing Record 49 of Set 8 | sistranda
# Processing Record 50 of Set 8 | kenai
# Processing Record 1 of Set 9 | okha
# Processing Record 2 of Set 9 | kijang
# Processing Record 3 of Set 9 | parana
# Processing Record 4 of Set 9 | beringovskiy
# Processing Record 5 of Set 9 | acari
# Processing Record 6 of Set 9 | gazanjyk
# Processing Record 7 of Set 9 | coquimbo
# Processing Record 8 of Set 9 | cairns
# Processing Record 9 of Set 9 | chapais
# Processing Record 10 of Set 9 | deputatskiy
# Processing Record 11 of Set 9 | dondo
# Processing Record 12 of Set 9 | toba
# Processing Record 13 of Set 9 | ludvika
# Processing Record 14 of Set 9 | basco
# Processing Record 15 of Set 9 | hami
# Processing Record 16 of Set 9 | gizo
# Processing Record 17 of Set 9 | vila franca do campo
# Processing Record 18 of Set 9 | kruisfontein
# Processing Record 19 of Set 9 | fallon
# Processing Record 20 of Set 9 | amuntai
# Processing Record 21 of Set 9 | meulaboh
# Processing Record 22 of Set 9 | faya
# Processing Record 23 of Set 9 | mizdah
# Processing Record 24 of Set 9 | zhigansk
# Processing Record 25 of Set 9 | palana
# Processing Record 26 of Set 9 | vryburg
# Processing Record 27 of Set 9 | lons-le-saunier
# Processing Record 28 of Set 9 | provost
# Processing Record 29 of Set 9 | esperance
# Processing Record 30 of Set 9 | merauke
# Processing Record 31 of Set 9 | artesia
# Processing Record 32 of Set 9 | padang
# Processing Record 33 of Set 9 | bundaberg
# Processing Record 34 of Set 9 | sibolga
# Processing Record 35 of Set 9 | hovd
# Processing Record 36 of Set 9 | liberal
# Processing Record 37 of Set 9 | svetlogorsk
# Processing Record 38 of Set 9 | alamos
# Processing Record 39 of Set 9 | manzil jamil
# City not found. Skipping...
# Processing Record 40 of Set 9 | nanortalik
# Processing Record 41 of Set 9 | takikawa
# Processing Record 42 of Set 9 | boa viagem
# Processing Record 43 of Set 9 | yerbogachen
# Processing Record 44 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 9 | taburao
# City not found. Skipping...
# Processing Record 46 of Set 9 | belmonte
# Processing Record 47 of Set 9 | jutai
# Processing Record 48 of Set 9 | marinha grande
# Processing Record 49 of Set 9 | keningau
# Processing Record 50 of Set 9 | koyelga
# Processing Record 1 of Set 10 | vila velha
# Processing Record 2 of Set 10 | lake city
# Processing Record 3 of Set 10 | pingliang
# Processing Record 4 of Set 10 | luanda
# Processing Record 5 of Set 10 | tiarei
# Processing Record 6 of Set 10 | slave lake
# Processing Record 7 of Set 10 | alofi
# Processing Record 8 of Set 10 | hamilton
# Processing Record 9 of Set 10 | egvekinot
# Processing Record 10 of Set 10 | high level
# Processing Record 11 of Set 10 | palauig
# Processing Record 12 of Set 10 | nemuro
# Processing Record 13 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 14 of Set 10 | luwuk
# Processing Record 15 of Set 10 | kinston
# Processing Record 16 of Set 10 | canchungo
# Processing Record 17 of Set 10 | pangkalanbuun
# Processing Record 18 of Set 10 | necochea
# Processing Record 19 of Set 10 | lhokseumawe
# Processing Record 20 of Set 10 | bako
# Processing Record 21 of Set 10 | caceres
# Processing Record 22 of Set 10 | adrar
# Processing Record 23 of Set 10 | la ronge
# Processing Record 24 of Set 10 | sur
# Processing Record 25 of Set 10 | port hardy
# Processing Record 26 of Set 10 | paldiski
# Processing Record 27 of Set 10 | stuttgart
# Processing Record 28 of Set 10 | trincomalee
# Processing Record 29 of Set 10 | guantanamo
# Processing Record 30 of Set 10 | krasnokholmskiy
# Processing Record 31 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 10 | rockport
# Processing Record 33 of Set 10 | presidencia roque saenz pena
# Processing Record 34 of Set 10 | innisfail
# Processing Record 35 of Set 10 | sotouboua
# Processing Record 36 of Set 10 | phan thiet
# Processing Record 37 of Set 10 | chifeng
# Processing Record 38 of Set 10 | arkhangelos
# City not found. Skipping...
# Processing Record 39 of Set 10 | turukhansk
# Processing Record 40 of Set 10 | pochutla
# Processing Record 41 of Set 10 | chumikan
# Processing Record 42 of Set 10 | taltal
# Processing Record 43 of Set 10 | kuzino
# Processing Record 44 of Set 10 | fort-shevchenko
# Processing Record 45 of Set 10 | kristiansund
# Processing Record 46 of Set 10 | itarema
# Processing Record 47 of Set 10 | asosa
# Processing Record 48 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 10 | saint-georges
# Processing Record 50 of Set 10 | nadvoitsy
# Processing Record 1 of Set 11 | allapalli
# Processing Record 2 of Set 11 | daura
# Processing Record 3 of Set 11 | biak
# Processing Record 4 of Set 11 | teguise
# Processing Record 5 of Set 11 | grindavik
# Processing Record 6 of Set 11 | nosivka
# Processing Record 7 of Set 11 | conceicao do araguaia
# Processing Record 8 of Set 11 | alta floresta
# Processing Record 9 of Set 11 | katherine
# Processing Record 10 of Set 11 | grande-riviere
# City not found. Skipping...
# Processing Record 11 of Set 11 | pacific grove
# Processing Record 12 of Set 11 | progreso
# Processing Record 13 of Set 11 | boyolangu
# Processing Record 14 of Set 11 | nabire
# Processing Record 15 of Set 11 | pangnirtung
# Processing Record 16 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 11 | novouzensk
# Processing Record 18 of Set 11 | surgut
# Processing Record 19 of Set 11 | san policarpo
# Processing Record 20 of Set 11 | chivay
# Processing Record 21 of Set 11 | saravan
# Processing Record 22 of Set 11 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 23 of Set 11 | huarmey
# Processing Record 24 of Set 11 | fairbanks
# Processing Record 25 of Set 11 | san joaquin
# Processing Record 26 of Set 11 | fiumicino
# Processing Record 27 of Set 11 | dhidhdhoo
# Processing Record 28 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 11 | arriaga
# Processing Record 30 of Set 11 | sorland
# Processing Record 31 of Set 11 | opuwo
# Processing Record 32 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 11 | salo
# Processing Record 34 of Set 11 | tromso
# Processing Record 35 of Set 11 | sioux lookout
# Processing Record 36 of Set 11 | half moon bay
# Processing Record 37 of Set 11 | hervey bay
# Processing Record 38 of Set 11 | derzhavinsk
# Processing Record 39 of Set 11 | sergeyevka
# Processing Record 40 of Set 11 | culebra
# Processing Record 41 of Set 11 | iraray
# Processing Record 42 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 11 | camargo
# Processing Record 46 of Set 11 | nizhniy kuranakh
# Processing Record 47 of Set 11 | bani
# Processing Record 48 of Set 11 | saurimo
# Processing Record 49 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 50 of Set 11 | tagbac
# Processing Record 1 of Set 12 | nalut
# Processing Record 2 of Set 12 | arman
# Processing Record 3 of Set 12 | narsaq
# Processing Record 4 of Set 12 | kolokani
# Processing Record 5 of Set 12 | honningsvag
# Processing Record 6 of Set 12 | maragheh
# Processing Record 7 of Set 12 | rincon
# Processing Record 8 of Set 12 | chattanooga
# Processing Record 9 of Set 12 | moree
# Processing Record 10 of Set 12 | labuhan
# Processing Record 11 of Set 12 | port hedland
# Processing Record 12 of Set 12 | midland
# Processing Record 13 of Set 12 | dezful
# Processing Record 14 of Set 12 | wagar
# Processing Record 15 of Set 12 | viedma
# Processing Record 16 of Set 12 | upernavik
# Processing Record 17 of Set 12 | semey
# Processing Record 18 of Set 12 | puerto palomas
# Processing Record 19 of Set 12 | lahaina
# Processing Record 20 of Set 12 | bolshaya murta
# City not found. Skipping...
# Processing Record 21 of Set 12 | kansanshi
# Processing Record 22 of Set 12 | thinadhoo
# Processing Record 23 of Set 12 | pangody
# Processing Record 24 of Set 12 | sao joao da barra
# Processing Record 25 of Set 12 | emilio carranza
# Processing Record 26 of Set 12 | salinopolis
# Processing Record 27 of Set 12 | esna
# Processing Record 28 of Set 12 | ketchikan
# Processing Record 29 of Set 12 | coihaique
# Processing Record 30 of Set 12 | copiapo
# Processing Record 31 of Set 12 | leningradskiy
# Processing Record 32 of Set 12 | mandalgovi
# Processing Record 33 of Set 12 | vavatenina
# Processing Record 34 of Set 12 | portage
# Processing Record 35 of Set 12 | skibbereen
# Processing Record 36 of Set 12 | leeuwarden
# Processing Record 37 of Set 12 | los pozos
# Processing Record 38 of Set 12 | rio grande
# Processing Record 39 of Set 12 | teya
# Processing Record 40 of Set 12 | pavlivka
# Processing Record 41 of Set 12 | amapa
# Processing Record 42 of Set 12 | puerto baquerizo moreno
# Processing Record 43 of Set 12 | olafsvik
# Processing Record 44 of Set 12 | nauta
# Processing Record 45 of Set 12 | lazaro cardenas
# Processing Record 46 of Set 12 | mangan
# Processing Record 47 of Set 12 | ha tinh
# Processing Record 48 of Set 12 | krasnyy chikoy
# Processing Record 49 of Set 12 | male
# Processing Record 50 of Set 12 | siyabuswa
# Processing Record 1 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 2 of Set 13 | vanavara
# Processing Record 3 of Set 13 | duyun
# Processing Record 4 of Set 13 | tilichiki
# Processing Record 5 of Set 13 | toora-khem
# Processing Record 6 of Set 13 | polunochnoye
# Processing Record 7 of Set 13 | horta
# Processing Record 8 of Set 13 | tome
# Processing Record 9 of Set 13 | gornopravdinsk
# Processing Record 10 of Set 13 | tocopilla
# Processing Record 11 of Set 13 | algodones
# Processing Record 12 of Set 13 | buraydah
# Processing Record 13 of Set 13 | ningan
# City not found. Skipping...
# Processing Record 14 of Set 13 | mackay
# Processing Record 15 of Set 13 | ozinki
# Processing Record 16 of Set 13 | genhe
# Processing Record 17 of Set 13 | port lincoln
# Processing Record 18 of Set 13 | eureka
# Processing Record 19 of Set 13 | vardo
# Processing Record 20 of Set 13 | acapulco
# Processing Record 21 of Set 13 | praia da vitoria
# Processing Record 22 of Set 13 | inhambane
# Processing Record 23 of Set 13 | koppal
# Processing Record 24 of Set 13 | yaan
# Processing Record 25 of Set 13 | port augusta
# Processing Record 26 of Set 13 | paamiut
# Processing Record 27 of Set 13 | atar
# Processing Record 28 of Set 13 | linguere
# Processing Record 29 of Set 13 | winslow
# Processing Record 30 of Set 13 | berea
# Processing Record 31 of Set 13 | rexburg
# Processing Record 32 of Set 13 | khovu-aksy
# Processing Record 33 of Set 13 | santa rosalia
# Processing Record 34 of Set 13 | baruun-urt
# Processing Record 35 of Set 13 | brandon
# Processing Record 36 of Set 13 | czersk
# Processing Record 37 of Set 13 | panjab
# Processing Record 38 of Set 13 | nagar
# Processing Record 39 of Set 13 | sorong
# Processing Record 40 of Set 13 | bathsheba
# Processing Record 41 of Set 13 | fengzhen
# Processing Record 42 of Set 13 | port keats
# Processing Record 43 of Set 13 | pleszew
# Processing Record 44 of Set 13 | chichimila
# Processing Record 45 of Set 13 | strezhevoy
# Processing Record 46 of Set 13 | manta
# Processing Record 47 of Set 13 | shubarkuduk
# Processing Record 48 of Set 13 | gorontalo
# Processing Record 49 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 13 | cooma
# Processing Record 1 of Set 14 | tazovskiy
# Processing Record 2 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 3 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 4 of Set 14 | waddan
# Processing Record 5 of Set 14 | cheremukhovo
# Processing Record 6 of Set 14 | maracaju
# Processing Record 7 of Set 14 | barra do garcas
# Processing Record 8 of Set 14 | altay
# Processing Record 9 of Set 14 | tabuk
# Processing Record 10 of Set 14 | erenhot
# Processing Record 11 of Set 14 | ales
# Processing Record 12 of Set 14 | lang suan
# Processing Record 13 of Set 14 | ust-kuyga
# Processing Record 14 of Set 14 | charleston
# Processing Record 15 of Set 14 | petrivka
# Processing Record 16 of Set 14 | chany
# Processing Record 17 of Set 14 | bandiagara
# Processing Record 18 of Set 14 | tadine
# Processing Record 19 of Set 14 | verona
# Processing Record 20 of Set 14 | padampur
# Processing Record 21 of Set 14 | briancon
# Processing Record 22 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 23 of Set 14 | suleja
# Processing Record 24 of Set 14 | novhorodka
# Processing Record 25 of Set 14 | sabang
# Processing Record 26 of Set 14 | eyl
# Processing Record 27 of Set 14 | raipur
# Processing Record 28 of Set 14 | namibe
# Processing Record 29 of Set 14 | isabela
# Processing Record 30 of Set 14 | sapa
# Processing Record 31 of Set 14 | savannah bight
# Processing Record 32 of Set 14 | bay roberts
# Processing Record 33 of Set 14 | yarkovo
# Processing Record 34 of Set 14 | sikonge
# Processing Record 35 of Set 14 | garissa
# Processing Record 36 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 37 of Set 14 | surman
# Processing Record 38 of Set 14 | nizwa
# Processing Record 39 of Set 14 | pedreiras
# Processing Record 40 of Set 14 | iisalmi
# Processing Record 41 of Set 14 | kodinsk
# Processing Record 42 of Set 14 | high rock
# Processing Record 43 of Set 14 | hoshiarpur
# Processing Record 44 of Set 14 | kedrovyy
# Processing Record 45 of Set 14 | beloha
# Processing Record 46 of Set 14 | san pedro
# Processing Record 47 of Set 14 | aleksandrov gay
# Processing Record 48 of Set 14 | agua verde
# Processing Record 49 of Set 14 | bayshore gardens
# Processing Record 50 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 1 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 2 of Set 15 | cheremkhovo
# Processing Record 3 of Set 15 | seoul
# Processing Record 4 of Set 15 | jiangdu
# Processing Record 5 of Set 15 | bondoukou
# Processing Record 6 of Set 15 | kytmanovo
# Processing Record 7 of Set 15 | sokoto
# Processing Record 8 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 9 of Set 15 | oum hadjer
# Processing Record 10 of Set 15 | monte alegre
# Processing Record 11 of Set 15 | ilam
# Processing Record 12 of Set 15 | chai badan
# Processing Record 13 of Set 15 | mitsamiouli
# Processing Record 14 of Set 15 | quesada
# Processing Record 15 of Set 15 | balkhash
# Processing Record 16 of Set 15 | jining
# Processing Record 17 of Set 15 | tunceli
# Processing Record 18 of Set 15 | surt
# Processing Record 19 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 15 | ordzhonikidze
# Processing Record 21 of Set 15 | tabarqah
# City not found. Skipping...
# Processing Record 22 of Set 15 | stamford
# Processing Record 23 of Set 15 | jasper
# Processing Record 24 of Set 15 | goleniow
# Processing Record 25 of Set 15 | urumqi
# Processing Record 26 of Set 15 | mawlaik
# Processing Record 27 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 15 | belaya gora
# Processing Record 29 of Set 15 | khorixas
# Processing Record 30 of Set 15 | asfi
# Processing Record 31 of Set 15 | iquique
# Processing Record 32 of Set 15 | ayame
# Processing Record 33 of Set 15 | salmon arm
# Processing Record 34 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 35 of Set 15 | zhaotong
# Processing Record 36 of Set 15 | partizanskoye
# Processing Record 37 of Set 15 | sechura
# Processing Record 38 of Set 15 | bentiu
# Processing Record 39 of Set 15 | aswan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 676

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Avarua      CK -21.2078 -159.7750     81.27        78          76
# 1         Ushuaia      AR -54.8000  -68.3000     42.46        75          40
# 2  Vestmannaeyjar      IS  63.4427  -20.2734     46.53        81         100
# 3      Tacuarembo      UY -31.7333  -55.9833     58.32        87         100
# 4          Atuona      PF  -9.8000 -139.0333     78.98        76          21
# 5     Yellowknife      CA  62.4560 -114.3525     27.12        63         100
# 6          Wajima      JP  37.4000  136.9000     57.60        59           3
# 7          Barrow      US  71.2906 -156.7887     30.22        86         100
# 8           Bluff      NZ -46.6000  168.3333     51.80        67          76
# 9    Bogorodskoye      RU  56.5500   37.8833     34.61        89          66
#
#    Wind Speed Current Description
# 0       13.20          light rain
# 1       24.16    scattered clouds
# 2        2.19     overcast clouds
# 3        3.87     overcast clouds
# 4       20.83          few clouds
# 5       19.57     overcast clouds
# 6       12.48           clear sky
# 7       14.97     overcast clouds
# 8        4.56       broken clouds
# 9        7.67       broken clouds

# %%
city_data_df.to_csv(r'weather_database\WeatherPy_Database.csv')
